# %%
import csv
import pandas as pd

# %%
with open("generic_tweets.txt", 'r', encoding='utf-8', errors='ignore') as file:
    file_data = file.read()

# %%
names2010 = pd.read_txt('generic_tweets.txt', names=["class","id","date","query","user","text"])
names2010
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7f5e1f809566> in <module>()
# ----> 1 names2010 = pd.read_txt('generic_tweets.txt', names=["class","id","date","query","user","text"])
#       2 names2010
#
# AttributeError: module 'pandas' has no attribute 'read_txt'

# %%
generic_tweet = pd.read_csv('US_airline_tweets.csv', names=['id', 'sentiment', 'negative_reason','user','retweet','text'])
names2010
# Out:
#                 id  sentiment              negative_reason             user  \
# 0               id  sentiment              negative_reason             user
# 1      5.70301E+17   positive                          NaN         jnardino
# 2      5.70301E+17   negative                   Bad Flight         jnardino
# 3      5.70301E+17   negative                   Can't Tell         jnardino
# 4      5.70301E+17   negative                   Can't Tell         jnardino
# 5      5.70301E+17   positive                          NaN       cjmcginnis
# 6        5.703E+17   positive                          NaN         dhepburn
# 7      5.70295E+17   positive                          NaN       YupitsTate
# 8       5.7029E+17   positive                          NaN     HyperCamiLax
# 9       5.7029E+17   positive                          NaN     HyperCamiLax
# 10     5.70287E+17   positive                          NaN     mollanderson
# ...
